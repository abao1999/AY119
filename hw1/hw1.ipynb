# %% [markdown]
# #AY 119 HW 1

# %% [markdown]
# Mount google drive

# %%
import os
from google.colab import drive   

drive.flush_and_unmount()
# mount the google drive to my Colab session
drive.mount('/content/gdrive')
# use the google drive in my Colab session
home_path = '/content/gdrive/My Drive/AY119'
print(os.listdir(home_path))
# Out:
# Mounted at /content/gdrive
# ['data']

# %% [markdown]
# Set up data path and load features

# %%
import sys
# datapath is the path to the data npy file for this assignment
datapath = os.path.join(home_path, 'data/dsfp_ztf_feats.npy')
sys.path.insert(1, datapath)

# %%
import numpy as np
# load features from datapath into numpy
feats = np.load(datapath)
print(feats)
# Out:
# [[1.72818508e+01 1.75515671e+01 1.65696695e-01 ... 2.45821470e+06
#   5.22394562e+00 0.00000000e+00]
#  [2.03205700e+01 2.08020535e+01 1.95894212e-01 ... 2.45821985e+06
#   5.51870108e+00 0.00000000e+00]
#  [2.04277248e+01 2.09223328e+01 2.00625002e-01 ... 2.45821985e+06
#   5.85641098e+00 0.00000000e+00]
#  ...
#  [2.11532211e+01 1.98009758e+01 2.08727643e-01 ... 2.45839065e+06
#   7.55207109e+00 0.00000000e+00]
#  [2.06950302e+01 1.97840366e+01 1.48797214e-01 ... 2.45839068e+06
#   8.50300980e+00 0.00000000e+00]
#  [2.06728306e+01 2.00290928e+01 1.62722468e-01 ... 2.45839068e+06
#   9.20202923e+00 0.00000000e+00]]

# %% [markdown]
# Assign column names to features within DataFrame object

# %%
COL_NAMES = ['diffmaglim', 'magpsf', 'sigmapsf', 'chipsf', 'magap', 'sigmagap',
             'distnr', 'magnr', 'sigmagnr', 'chinr', 'sharpnr', 'sky',
             'magdiff', 'fwhm', 'classtar', 'mindtoedge', 'magfromlim', 'seeratio',
             'aimage', 'bimage', 'aimagerat', 'bimagerat', 'elong', 'nneg',
             'nbad', 'ssdistnr', 'ssmagnr', 'sumrat', 'magapbig', 'sigmagapbig',
             'ndethist', 'ncovhist', 'jdstarthist', 'jdendhist', 'scorr', 'label']

# %%
import pandas as pd
# create dataframe with feats assigned columns given by COL_NAMES
df = pd.DataFrame(data=feats, columns=COL_NAMES)
# print(df.head(5))

# %%
df
# Out:
#       diffmaglim     magpsf  sigmapsf  ...     jdendhist      scorr  label
# 0      17.281851  17.551567  0.165697  ...  2.458215e+06   5.223946    0.0
# 1      20.320570  20.802053  0.195894  ...  2.458220e+06   5.518701    0.0
# 2      20.427725  20.922333  0.200625  ...  2.458220e+06   5.856411    0.0
# 3      20.427725  20.703472  0.172896  ...  2.458220e+06   5.573197    0.0
# 4      20.427725  20.704222  0.171942  ...  2.458220e+06   6.145004    0.0
# ...          ...        ...       ...  ...           ...        ...    ...
# 3185   20.448118  17.893902  0.137054  ...  2.458390e+06   5.236978    0.0
# 3186   20.817453  19.790672  0.179343  ...  2.458391e+06  14.190198    0.0
# 3187   21.153221  19.800976  0.208728  ...  2.458391e+06   7.552071    0.0
# 3188   20.695030  19.784037  0.148797  ...  2.458391e+06   8.503010    0.0
# 3189   20.672831  20.029093  0.162722  ...  2.458391e+06   9.202029    0.0
#
# [3190 rows x 36 columns]

# %%
df['diffmaglim'].to_numpy()
# Out:
# array([17.28185081, 20.32056999, 20.42772484, ..., 21.15322113,
#        20.69503021, 20.67283058])

# %% [markdown]
# Plotting functions for visualization

# %%
import matplotlib.pyplot as plt

def plot_features_pairwise_from_df(df, x_feat_name, y_feat_name):
    '''
    Takes the dataframe df, gets the numpy form of the x and y features based on 
    x_feat_name and y_feat_name, and then plots them against each other
    using matplotlib pyplot's scatterplot
    '''
    x = df[x_feat_name].to_numpy()
    y = df[y_feat_name].to_numpy()

    plt.figure(figsize=(8, 6), dpi=100)
    plt.scatter(x, y)
    plt.xlabel(x_feat_name)
    plt.ylabel(y_feat_name)
    # plt.legend(loc='upper right')
    plt.title("{} vs. {}".format(y_feat_name, x_feat_name))
    plt.show()

# %%
plot_features_pairwise_from_df(df, 'distnr', 'magfromlim')

# %%
plot_features_pairwise_from_df(df, 'classtar', 'magfromlim')

# %% [markdown]
# Create and show covariance matrix among the features

# %%
# get covariance matrix covMatrix directly from pandas Dataframe
covMatrix = pd.DataFrame.cov(df)
covMatrix
# Out:
#              diffmaglim     magpsf  ...       scorr      label
# diffmaglim     0.360484   0.256572  ...   -0.082333   0.034261
# magpsf         0.256572   1.397656  ...   -9.663816  -0.009063
# sigmapsf       0.002627   0.044371  ...   -0.471641   0.001093
# chipsf        -0.184555 -79.524802  ...  938.122145  -4.558320
# magap          0.279541   1.290493  ...  -10.223764   0.035961
# sigmagap       0.003352   0.066460  ...   -0.649553   0.005752
# distnr        -7.276704 -75.294166  ...  164.237341  21.951990
# magnr         -7.210780 -75.466278  ...  163.662716  22.600234
# sigmagnr      -7.020165 -75.306150  ...  159.981687  22.342669
# chinr         -7.316514 -76.391286  ...  174.257642  22.234441
# sharpnr       -7.021044 -75.340632  ...  160.389226  22.354743
# sky           -2.484739  -2.518573  ...   -4.997278  -0.390822
# magdiff        0.022970  -0.107163  ...   -0.559949   0.045024
# fwhm          -0.819982  -3.191249  ...   78.427513  -0.923409
# classtar      -0.011693   0.017632  ...   -1.842227   0.047325
# mindtoedge     4.696228 -17.205298  ...   79.179628  -1.134538
# magfromlim     0.080943  -1.033921  ...   10.141431  -0.001700
# seeratio       0.334689 -12.781075  ...  179.499104   0.333731
# aimage        -0.157351  -0.317205  ...   11.114727  -0.169900
# bimage        -0.121707  -0.241207  ...    8.417739  -0.109079
# aimagerat      0.285059 -12.884607  ...  182.346807   0.266365
# bimagerat      0.291075 -12.909774  ...  182.658510   0.275135
# elong         -0.010306  -0.010330  ...    0.667403  -0.036532
# nneg           0.154466   0.949272  ...  -13.944986  -0.011543
# nbad          -0.198490  -0.359073  ...    5.785144  -0.218250
# ssdistnr      -4.013601 -21.121223  ...  765.451262 -16.560335
# ssmagnr       -4.016726 -21.161426  ...  765.519060 -16.537393
# sumrat         0.000306  -0.009232  ...    0.204434   0.004775
# magapbig       0.318967   1.259406  ...  -11.761461   0.117048
# sigmagapbig   -0.001917   0.085782  ...   -0.837872   0.008814
# ndethist       0.188559  -3.010178  ...    5.542892  -0.004983
# ncovhist       2.061978  12.437551  ...  -63.321074  -3.579888
# jdstarthist    4.593245   2.464832  ... -105.621518   7.065547
# jdendhist      8.724785  -1.248331  ... -111.415525   8.711078
# scorr         -0.082333  -9.663816  ...  248.613537  -0.299844
# label          0.034261  -0.009063  ...   -0.299844   0.194193
#
# [36 rows x 36 columns]

# %%
import seaborn as sn

#plot the covariance matrix covMatrix
plt.figure(figsize=(8, 6), dpi=100)
sn.heatmap(covMatrix, annot=False, fmt='.2g')
plt.title('Feature Covariances')
plt.show()
